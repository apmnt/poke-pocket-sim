# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('test_data.csv')

# Display the DataFrame
df
# Out:
#     turn active_player                                 match_state_before  \
# 0      1            p1  {"turn": 1, "player1": {"name": "p1", "hand": ...
# 1      2            p2  {"turn": 2, "player1": {"name": "p1", "hand": ...
# 2      3            p1  {"turn": 3, "player1": {"name": "p1", "hand": ...
# 3      4            p2  {"turn": 4, "player1": {"name": "p1", "hand": ...
# 4      5            p1  {"turn": 5, "player1": {"name": "p1", "hand": ...
# 5      6            p2  {"turn": 6, "player1": {"name": "p1", "hand": ...
# 6      7            p1  {"turn": 7, "player1": {"name": "p1", "hand": ...
# 7      8            p2  {"turn": 8, "player1": {"name": "p1", "hand": ...
# 8      9            p1  {"turn": 9, "player1": {"name": "p1", "hand": ...
# 9     10            p2  {"turn": 10, "player1": {"name": "p1", "hand":...
# 10    11            p1  {"turn": 11, "player1": {"name": "p1", "hand":...
# 11    12            p2  {"turn": 12, "player1": {"name": "p1", "hand":...
# ...

# %%
df.actions_taken
# Out:
# 0     [{"name": "Set Ralts as active card", "action_...
# 1     [{"name": "Set Ralts as active card", "action_...
# 2     [{"name": "Add psychic energy to Card(Ralts wi...
# 3     [{"name": "Add Mewtwo EX to bench", "action_ty...
# 4     [{"name": "Evolve Kirlia to Gardevoir", "actio...
# 5     [{"name": "Add psychic energy to Card(Mewtwo E...
# 6     [{"name": "Use ability Psy Shadow on Gardevoir...
# 7     [{"name": "Evolve Kirlia to Gardevoir", "actio...
# 8     [{"name": "Mewtwo EX use psychic_sphere", "act...
# 9     [{"name": "Add psychic energy to Card(Gardevoi...
# 10    [{"name": "Add psychic energy to Card(Mewtwo E...
# 11    [{"name": "Add psychic energy to Card(Mewtwo E...
# 12    [{"name": "Use ability Psy Shadow on Gardevoir...
# 13    [{"name": "Add psychic energy to Card(Gardevoi...
# 14    [{"name": "Use ability Psy Shadow on Mewtwo EX...
# 15    [{"name": "Add psychic energy to Card(Mewtwo E...
# 16    [{"name": "Add psychic energy to Card(Gardevoi...
# ...

# %%
import json

match_state_before_dict = json.loads(df.match_state_before[0])
match_state_before_dict
# Out:
# {'turn': 1,
#  'player1': {'name': 'p1',
#   'hand': [{'id': '1c16deaa-c02d-4eaf-af5a-f19453eee42f',
#     'name': 'Ralts',
#     'max_hp': 60,
#     'hp': 60,
#     'type': 'psychic',
#     'energies': {},
#     'attacks': ['ram'],
#     'retreat_cost': 1,
#     'ability': None,
#     'conditions': [],
#     'weakness': 'DARKNESS',
#     'is_basic': True,
#     'is_ex': False,
#     'has_used_ability': False,
#     'evolves_from': None,
#     'can_evolve': False},
#    {'id': 'a84094b9-1b03-47d9-ad56-ee694fc70147',
#     'name': 'Kirlia',
#     'max_hp': 80,
#     'hp': 80,
#     'type': 'psychic',
#     'energies': {},
#     'attacks': ['smack'],
#     'retreat_cost': 1,
#     'ability': None,
#     'conditions': [],
#     'weakness': 'DARKNESS',
#     'is_basic': False,
#     'is_ex': False,
#     'has_used_ability': False,
#     'evolves_from': 'RALTS',
#     'can_evolve': False},
#    {'id': '664d9c12-5fbc-4598-8bb6-a8ff82fceae5',
#     'name': 'Gardevoir',
#     'max_hp': 110,
# ...

# %%
df.match_state_after
# Out:
# 0     {"turn": 1, "player1": {"name": "p1", "hand": ...
# 1     {"turn": 2, "player1": {"name": "p1", "hand": ...
# 2     {"turn": 3, "player1": {"name": "p1", "hand": ...
# 3     {"turn": 4, "player1": {"name": "p1", "hand": ...
# 4     {"turn": 5, "player1": {"name": "p1", "hand": ...
# 5     {"turn": 6, "player1": {"name": "p1", "hand": ...
# 6     {"turn": 7, "player1": {"name": "p1", "hand": ...
# 7     {"turn": 8, "player1": {"name": "p1", "hand": ...
# 8     {"turn": 9, "player1": {"name": "p1", "hand": ...
# 9     {"turn": 10, "player1": {"name": "p1", "hand":...
# 10    {"turn": 11, "player1": {"name": "p1", "hand":...
# 11    {"turn": 12, "player1": {"name": "p1", "hand":...
# 12    {"turn": 13, "player1": {"name": "p1", "hand":...
# 13    {"turn": 14, "player1": {"name": "p1", "hand":...
# 14    {"turn": 15, "player1": {"name": "p1", "hand":...
# 15    {"turn": 16, "player1": {"name": "p1", "hand":...
# 16    {"turn": 17, "player1": {"name": "p1", "hand":...
# ...
